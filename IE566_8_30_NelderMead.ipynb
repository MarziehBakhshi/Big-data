# %%
import numpy as np
import random
from numpy.linalg import inv

# %%
def NelderMead(x,func):
    global norm_f
    alpha = 1
    gamma = 2
    beta = 0.5
    delta = 0.5
    
    A=np.delete(x, (0) , axis=0)
    for i in range(n):
        for j in range(n):
            A[i][j] = A[i][j] - x[0][j]

    
    # exception for handeling degeneracy
    try:
        inverse = np.linalg.inv(A)
    except np.linalg.LinAlgError:
        print('The vertices are degenerate.') # Not invertible. Skip this one.
        pass
    else:
        print('The vertices are not degenerate.')
        
        print('x = ' , x)
        f_array=np.array([0. for i in range(n+1)]) # arrray of f(x) 
        for i in range(n+1):
            f_array[i]=func(x[i])
        print('f(x) = ' , f_array)
        current_f = f_array
        

        
        f_h = max(f_array)
        index_h = np.where(f_array==f_h)[0] # the first index of the worst point
        x_h = x[int(index_h[0])] # worst point
        
        f_l = min(f_array)
        index_l = np.where(f_array==f_l)[0] # the first index of the best point
        x_l = x[int(index_l[0])] # best point
        
        f_array2 = np.delete(f_array, (int(index_h[0])) , axis=0)
        f_s = max(f_array2)
        index_s = np.where(f_array2==f_s)[0] # the first index of second worst point
        x_s = x[int(index_s[0])] # second worst point
        
        y = np.delete(x, (int(index_h[0])) , axis=0) # x without the worst point
        c=y.sum(axis=0)/n # centriod
        
        x_r = c + alpha*(c-x_h)
        f_r = func(x_r)
        
        print('f_l = ' , f_l)
        print('f_s = ' , f_s)
        print('f_h = ' , f_h)
        print('f_r = ' , f_r) 
        
        if f_l <= f_r and f_r < f_s:
            print('reflection, replace x_h by x_r')
            for i in range(n):
                x[int(index_h[0])][i]=x_r[i]
            print('new x = ' , x)    
        elif f_r < f_l:
            print('expansion')
            x_e = c + gamma*(x_r -c)
            f_e = func(x_e)
            if f_e < f_r:
                print('replace x_h by x_e')
                for i in range(n):
                    x[int(index_h[0])][i]=x_e[i]
                print('new x = ' , x)    
            else:
                print('replace x_h by x_r')
                for i in range(n):
                    x[int(index_h[0])][i]=x_r[i]
                print('new x = ' , x)    
        elif f_r >= f_s:
            print('contraction')           
            if f_s <= f_r and f_r < f_h:
                x_c = c + beta*(x_r -c)
                f_c = func(x_c)
                if f_c <= f_r:                  
                    print('replace x_h by x_c')
                    for i in range(n):
                        x[int(index_h[0])][i]=x_c[i]
                    print('new x = ' , x)    
                else:
                    print('shrink')
                    for i in range(n+1):
                        if i != int(index_l[0]):
                            for j in range(n):               
                                x[i][j] = x[i][j] - delta*x[i][j]
                    print('x_shrinked=' , x)        
            if f_r >= f_h:
                x_c = c + beta*(x_h -c)
                f_c = func(x_c)
                if f_c < f_h:                  
                    print('replace x_h by x_c')
                    for i in range(n):
                        x[int(index_h[0])][i]=x_c[i]
                    print('new x = ' , x)    
                else:
                    print('shrink')
                    for i in range(n+1):
                        if i != int(index_l[0]):
                            for j in range(n):               
                                x[i][j] = x[i][j] - delta*x[i][j]
                    print('x_shrinked=' , x)
            
        
        f_array=np.array([0. for i in range(n+1)]) # arrray of f(x) 
        for i in range(n+1):
            f_array[i]=func(x[i])
        diff_f = abs(np.subtract(f_array , current_f))
        norm_f = max(diff_f) # norm infinity
        print('norm_f = ' , norm_f)

# %%
n=2
x=np.array( [ np.array([0. for i in range(n)]) for j in range(n+1) ] )
for i in range(n+1):
    for j in range(n):
        x[i][j]= np.random.randint(1,5) + 0.1*np.random.randint(1,10)
        
def rosen(x):
    return 100*(x[1]-x[0]**2)**2 + (1-x[0])**2

# %%
for i in range(20):    
    NelderMead(x,rosen)
    print('=================', 'i =',i, '=================')
# Out:
# The vertices are not degenerate.
# x =  [[1.8 4.5]
#  [2.5 4.6]
#  [4.3 2.4]]
# f(x) =  [  159.4   274.5 25899.7]
# f_l =  159.39999999999992
# f_s =  274.5000000000001
# f_h =  25899.7
# f_r =  4489.999999999999
# contraction
# replace x_h by x_c
# new x =  [[1.8   4.5  ]
#  [2.5   4.6  ]
#  [1.075 5.625]]
# norm_f =  23902.1630859375
# ================= i = 0 =================
# The vertices are not degenerate.
# x =  [[1.8   4.5  ]
#  [2.5   4.6  ]
#  [1.075 5.625]]
# f(x) =  [ 159.4         274.5        1997.53691406]
# f_l =  159.39999999999992
# f_s =  274.5000000000001
# f_h =  1997.5369140625003
# f_r =  4801.378789062498
# contraction
# replace x_h by x_c
# new x =  [[1.8    4.5   ]
#  [2.5    4.6   ]
#  [1.6125 5.0875]]
# norm_f =  1378.4738647460936
# ================= i = 1 =================
# The vertices are not degenerate.
# x =  [[1.8    4.5   ]
#  [2.5    4.6   ]
#  [1.6125 5.0875]]
# f(x) =  [159.4        274.5        619.06304932]
# f_l =  159.39999999999992
# f_s =  274.5000000000001
# f_h =  619.0630493164067
# f_r =  1033.3579711914067
# contraction
# replace x_h by x_c
# new x =  [[1.8     4.5    ]
#  [2.5     4.6    ]
#  [1.88125 4.81875]]
# norm_f =  454.53643539428754
# ================= i = 2 =================
# The vertices are not degenerate.
# x =  [[1.8     4.5    ]
#  [2.5     4.6    ]
#  [1.88125 4.81875]]
# f(x) =  [159.4        274.5        164.52661392]
# f_l =  159.39999999999992
# f_s =  164.52661392211917
# f_h =  274.5000000000001
# f_r =  1104.5305690002442
# contraction
# replace x_h by x_c
# new x =  [[1.8       4.5      ]
#  [2.1703125 4.6296875]
#  [1.88125   4.81875  ]]
# norm_f =  272.48123473107825
# ================= i = 3 =================
# The vertices are not degenerate.
# x =  [[1.8       4.5      ]
#  [2.1703125 4.6296875]
#  [1.88125   4.81875  ]]
# f(x) =  [159.4          2.01876527 164.52661392]
# f_l =  2.0187652689218747
# f_s =  159.39999999999992
# f_h =  164.52661392211917
# f_r =  1.469556179642717
# expansion
# replace x_h by x_r
# new x =  [[1.8       4.5      ]
#  [2.1703125 4.6296875]
#  [2.0890625 4.3109375]]
# norm_f =  163.05705774247645
# ================= i = 4 =================
# The vertices are not degenerate.
# x =  [[1.8       4.5      ]
#  [2.1703125 4.6296875]
#  [2.0890625 4.3109375]]
# f(x) =  [159.4          2.01876527   1.46955618]
# f_l =  1.469556179642717
# f_s =  2.0187652689218747
# f_h =  159.39999999999992
# f_r =  260.66414200782884
# contraction
# replace x_h by x_c
# new x =  [[1.96484375 4.48515625]
#  [2.1703125  4.6296875 ]
#  [2.0890625  4.3109375 ]]
# norm_f =  119.46339485105128
# ================= i = 5 =================
# The vertices are not degenerate.
# x =  [[1.96484375 4.48515625]
#  [2.1703125  4.6296875 ]
#  [2.0890625  4.3109375 ]]
# f(x) =  [39.93660515  2.01876527  1.46955618]
# f_l =  1.469556179642717
# f_s =  2.0187652689218747
# f_h =  39.93660514894864
# f_r =  67.18944154147096
# contraction
# replace x_h by x_c
# new x =  [[2.04726563 4.47773437]
#  [2.1703125  4.6296875 ]
#  [2.0890625  4.3109375 ]]
# norm_f =  30.635176487972462
# ================= i = 6 =================
# The vertices are not degenerate.
# x =  [[2.04726563 4.47773437]
#  [2.1703125  4.6296875 ]
#  [2.0890625  4.3109375 ]]
# f(x) =  [9.30142866 2.01876527 1.46955618]
# f_l =  1.469556179642717
# f_s =  2.0187652689218747
# f_h =  9.301428660976175
# f_r =  20.005442530813244
# contraction
# replace x_h by x_c
# new x =  [[2.08847656 4.47402344]
#  [2.1703125  4.6296875 ]
#  [2.0890625  4.3109375 ]]
# norm_f =  6.855763564132926
# ================= i = 7 =================
# The vertices are not degenerate.
# x =  [[2.08847656 4.47402344]
#  [2.1703125  4.6296875 ]
#  [2.0890625  4.3109375 ]]
# f(x) =  [2.4456651  2.01876527 1.46955618]
# f_l =  1.469556179642717
# f_s =  2.0187652689218747
# f_h =  2.445665096843249
# f_r =  7.432371490958793
# contraction
# replace x_h by x_c
# new x =  [[2.10908203 4.47216797]
#  [2.1703125  4.6296875 ]
#  [2.0890625  4.3109375 ]]
# norm_f =  1.1582852159608796
# ================= i = 8 =================
# The vertices are not degenerate.
# x =  [[2.10908203 4.47216797]
#  [2.1703125  4.6296875 ]
#  [2.0890625  4.3109375 ]]
# f(x) =  [1.28737988 2.01876527 1.46955618]
# f_l =  1.2873798808823693
# f_s =  1.469556179642717
# f_h =  2.0187652689218747
# f_r =  1.227133439590223
# expansion
# replace x_h by x_r
# new x =  [[2.10908203 4.47216797]
#  [2.02783203 4.15341797]
#  [2.0890625  4.3109375 ]]
# norm_f =  0.7916318293316518
# ================= i = 9 =================
# The vertices are not degenerate.
# x =  [[2.10908203 4.47216797]
#  [2.02783203 4.15341797]
#  [2.0890625  4.3109375 ]]
# f(x) =  [1.28737988 1.22713344 1.46955618]
# f_l =  1.227133439590223
# f_s =  1.2873798808823693
# f_h =  1.469556179642717
# f_r =  2.5609415777470774
# contraction
# replace x_h by x_c
# new x =  [[2.10908203 4.47216797]
#  [2.02783203 4.15341797]
#  [2.07875977 4.31186523]]
# norm_f =  0.29704086832755583
# ================= i = 10 =================
# The vertices are not degenerate.
# x =  [[2.10908203 4.47216797]
#  [2.02783203 4.15341797]
#  [2.07875977 4.31186523]]
# f(x) =  [1.28737988 1.22713344 1.17251531]
# f_l =  1.1725153113151612
# f_s =  1.227133439590223
# f_h =  1.2873798808823693
# f_r =  0.9959682044704918
# expansion
# replace x_h by x_e
# new x =  [[1.94172363 3.75358887]
#  [2.02783203 4.15341797]
#  [2.07875977 4.31186523]]
# norm_f =  0.3726414711839823
# ================= i = 11 =================
# The vertices are not degenerate.
# x =  [[1.94172363 3.75358887]
#  [2.02783203 4.15341797]
#  [2.07875977 4.31186523]]
# f(x) =  [0.91473841 1.22713344 1.17251531]
# f_l =  0.914738409698387
# f_s =  1.1725153113151612
# f_h =  1.227133439590223
# f_r =  1.3290263166119334
# contraction
# replace x_h by x_c
# new x =  [[1.94172363 3.75358887]
#  [2.01903687 4.09307251]
#  [2.07875977 4.31186523]]
# norm_f =  0.16126518067643913
# ================= i = 12 =================
# The vertices are not degenerate.
# x =  [[1.94172363 3.75358887]
#  [2.01903687 4.09307251]
#  [2.07875977 4.31186523]]
# f(x) =  [0.91473841 1.06586826 1.17251531]
# f_l =  0.914738409698387
# f_s =  1.0658682589137838
# f_h =  1.1725153113151612
# f_r =  0.7830098579628769
# expansion
# replace x_h by x_e
# new x =  [[1.94172363 3.75358887]
#  [2.01903687 4.09307251]
#  [1.78362122 3.1462616 ]]
# norm_f =  0.43565160223301613
# ================= i = 13 =================
# The vertices are not degenerate.
# x =  [[1.94172363 3.75358887]
#  [2.01903687 4.09307251]
#  [1.78362122 3.1462616 ]]
# f(x) =  [0.91473841 1.06586826 0.73686371]
# f_l =  0.736863709082145
# f_s =  0.914738409698387
# f_h =  1.0658682589137838
# f_r =  1.5952680189316282
# contraction
# replace x_h by x_c
# new x =  [[1.94172363 3.75358887]
#  [1.94085464 3.77149887]
#  [1.78362122 3.1462616 ]]
# norm_f =  0.17856121513715295
# ================= i = 14 =================
# The vertices are not degenerate.
# x =  [[1.94172363 3.75358887]
#  [1.94085464 3.77149887]
#  [1.78362122 3.1462616 ]]
# f(x) =  [0.91473841 0.88730704 0.73686371]
# f_l =  0.736863709082145
# f_s =  0.8873070437766308
# f_h =  0.914738409698387
# f_r =  0.6323960999644006
# expansion
# replace x_h by x_e
# new x =  [[1.70326653 2.86946297]
#  [1.94085464 3.77149887]
#  [1.78362122 3.1462616 ]]
# norm_f =  0.3199577341037042
# ================= i = 15 =================
# The vertices are not degenerate.
# x =  [[1.70326653 2.86946297]
#  [1.94085464 3.77149887]
#  [1.78362122 3.1462616 ]]
# f(x) =  [0.59478068 0.88730704 0.73686371]
# f_l =  0.5947806755946828
# f_s =  0.736863709082145
# f_h =  0.8873070437766308
# f_r =  2.4295372983942545
# contraction
# replace x_h by x_c
# new x =  [[1.70326653 2.86946297]
#  [1.84214926 3.38968058]
#  [1.78362122 3.1462616 ]]
# norm_f =  0.17662224414495376
# ================= i = 16 =================
# The vertices are not degenerate.
# x =  [[1.70326653 2.86946297]
#  [1.84214926 3.38968058]
#  [1.78362122 3.1462616 ]]
# f(x) =  [0.59478068 0.7106848  0.73686371]
# f_l =  0.5947806755946828
# f_s =  0.7106847996316771
# f_h =  0.736863709082145
# f_r =  0.5883624377881531
# expansion
# replace x_h by x_r
# new x =  [[1.70326653 2.86946297]
#  [1.84214926 3.38968058]
#  [1.76179457 3.11288195]]
# norm_f =  0.14850127129399193
# ================= i = 17 =================
# The vertices are not degenerate.
# x =  [[1.70326653 2.86946297]
#  [1.84214926 3.38968058]
#  [1.76179457 3.11288195]]
# f(x) =  [0.59478068 0.7106848  0.58836244]
# f_l =  0.5883624377881531
# f_s =  0.5947806755946828
# f_h =  0.7106847996316771
# f_r =  0.5575859256255922
# expansion
# replace x_h by x_r
# new x =  [[1.70326653 2.86946297]
#  [1.62291183 2.59266434]
#  [1.76179457 3.11288195]]
# norm_f =  0.1530988740060849
# ================= i = 18 =================
# The vertices are not degenerate.
# x =  [[1.70326653 2.86946297]
#  [1.62291183 2.59266434]
#  [1.76179457 3.11288195]]
# f(x) =  [0.59478068 0.55758593 0.58836244]
# f_l =  0.5575859256255922
# f_s =  0.5883624377881531
# f_h =  0.5947806755946828
# f_r =  0.47218062714850145
# expansion
# replace x_h by x_r
# new x =  [[1.68143988 2.83608332]
#  [1.62291183 2.59266434]
#  [1.76179457 3.11288195]]
# norm_f =  0.12260004844618139
# ================= i = 19 =================

# %%
i=0 
norm_f=10
while  norm_f > 0.01:
    print('=================', 'i =',i, '=================')
    NelderMead(x,rosen)
    i=i+1
# Out:
# ================= i = 0 =================
# The vertices are not degenerate.
# x =  [[1.68143988 2.83608332]
#  [1.62291183 2.59266434]
#  [1.76179457 3.11288195]]
# f(x) =  [0.47218063 0.55758593 0.58836244]
# f_l =  0.47218062714850145
# f_s =  0.5575859256255922
# f_h =  0.5883624377881531
# f_r =  0.6990784320785732
# contraction
# replace x_h by x_c
# new x =  [[1.68143988 2.83608332]
#  [1.62291183 2.59266434]
#  [1.70698521 2.91362789]]
# norm_f =  0.08853143739738889
# ================= i = 1 =================
# The vertices are not degenerate.
# x =  [[1.68143988 2.83608332]
#  [1.62291183 2.59266434]
#  [1.70698521 2.91362789]]
# f(x) =  [0.47218063 0.55758593 0.499831  ]
# f_l =  0.47218062714850145
# f_s =  0.4998310003907642
# f_h =  0.5575859256255922
# f_r =  0.7460891036830455
# contraction
# replace x_h by x_c
# new x =  [[1.68143988 2.83608332]
#  [1.65856219 2.73375997]
#  [1.70698521 2.91362789]]
# norm_f =  0.09474817237376709
# ================= i = 2 =================
# The vertices are not degenerate.
# x =  [[1.68143988 2.83608332]
#  [1.65856219 2.73375997]
#  [1.70698521 2.91362789]]
# f(x) =  [0.47218063 0.46283775 0.499831  ]
# f_l =  0.4628377532518251
# f_s =  0.47218062714850145
# f_h =  0.4998310003907642
# f_r =  0.4117955802623824
# expansion
# replace x_h by x_e
# new x =  [[1.68143988 2.83608332]
#  [1.65856219 2.73375997]
#  [1.59603268 2.52750916]]
# norm_f =  0.10532789362999984
# ================= i = 3 =================
# The vertices are not degenerate.
# x =  [[1.68143988 2.83608332]
#  [1.65856219 2.73375997]
#  [1.59603268 2.52750916]]
# f(x) =  [0.47218063 0.46283775 0.39450311]
# f_l =  0.3945031067607644
# f_s =  0.4628377532518251
# f_h =  0.47218062714850145
# f_r =  0.5748283765129143
# contraction
# replace x_h by x_c
# new x =  [[1.65436865 2.73335894]
#  [1.65856219 2.73375997]
#  [1.59603268 2.52750916]]
# norm_f =  0.042703008599006775
# ================= i = 4 =================
# The vertices are not degenerate.
# x =  [[1.65436865 2.73335894]
#  [1.65856219 2.73375997]
#  [1.59603268 2.52750916]]
# f(x) =  [0.42947762 0.46283775 0.39450311]
# f_l =  0.3945031067607644
# f_s =  0.4294776185494947
# f_h =  0.4628377532518251
# f_r =  0.3549572277864904
# expansion
# replace x_h by x_e
# new x =  [[1.65436865 2.73335894]
#  [1.55847762 2.4237822 ]
#  [1.59603268 2.52750916]]
# norm_f =  0.148369730603364
# ================= i = 5 =================
# The vertices are not degenerate.
# x =  [[1.65436865 2.73335894]
#  [1.55847762 2.4237822 ]
#  [1.59603268 2.52750916]]
# f(x) =  [0.42947762 0.31446802 0.39450311]
# f_l =  0.3144680226484611
# f_s =  0.3945031067607644
# f_h =  0.4294776185494947
# f_r =  0.355718019428772
# reflection, replace x_h by x_r
# new x =  [[1.50014164 2.21793242]
#  [1.55847762 2.4237822 ]
#  [1.59603268 2.52750916]]
# norm_f =  0.07375959912072266
# ================= i = 6 =================
# The vertices are not degenerate.
# x =  [[1.50014164 2.21793242]
#  [1.55847762 2.4237822 ]
#  [1.59603268 2.52750916]]
# f(x) =  [0.35571802 0.31446802 0.39450311]
# f_l =  0.3144680226484611
# f_s =  0.355718019428772
# f_h =  0.3945031067607644
# f_r =  0.27625673266817713
# expansion
# replace x_h by x_r
# new x =  [[1.50014164 2.21793242]
#  [1.55847762 2.4237822 ]
#  [1.46258658 2.11420547]]
# norm_f =  0.11824637409258726
# ================= i = 7 =================
# The vertices are not degenerate.
# x =  [[1.50014164 2.21793242]
#  [1.55847762 2.4237822 ]
#  [1.46258658 2.11420547]]
# f(x) =  [0.35571802 0.31446802 0.27625673]
# f_l =  0.27625673266817713
# f_s =  0.3144680226484611
# f_h =  0.355718019428772
# f_r =  0.2760523201844305
# expansion
# replace x_h by x_r
# new x =  [[1.52092256 2.32005525]
#  [1.55847762 2.4237822 ]
#  [1.46258658 2.11420547]]
# norm_f =  0.07966569924434153
# ================= i = 8 =================
# The vertices are not degenerate.
# x =  [[1.52092256 2.32005525]
#  [1.55847762 2.4237822 ]
#  [1.46258658 2.11420547]]
# f(x) =  [0.27605232 0.31446802 0.27625673]
# f_l =  0.2760523201844305
# f_s =  0.27625673266817713
# f_h =  0.3144680226484611
# f_r =  0.22160265743345736
# expansion
# replace x_h by x_r
# new x =  [[1.52092256 2.32005525]
#  [1.42503152 2.01047852]
#  [1.46258658 2.11420547]]
# norm_f =  0.09286536521500371
# ================= i = 9 =================
# The vertices are not degenerate.
# x =  [[1.52092256 2.32005525]
#  [1.42503152 2.01047852]
#  [1.46258658 2.11420547]]
# f(x) =  [0.27605232 0.22160266 0.27625673]
# f_l =  0.22160265743345736
# f_s =  0.2760523201844305
# f_h =  0.27625673266817713
# f_r =  0.25908171492714305
# reflection, replace x_h by x_r
# new x =  [[1.52092256 2.32005525]
#  [1.42503152 2.01047852]
#  [1.4833675  2.2163283 ]]
# norm_f =  0.017175017741034082
# ================= i = 10 =================
# The vertices are not degenerate.
# x =  [[1.52092256 2.32005525]
#  [1.42503152 2.01047852]
#  [1.4833675  2.2163283 ]]
# f(x) =  [0.27605232 0.22160266 0.25908171]
# f_l =  0.22160265743345736
# f_s =  0.25908171492714305
# f_h =  0.2760523201844305
# f_r =  0.183771253491481
# expansion
# replace x_h by x_r
# new x =  [[1.38747646 1.90675157]
#  [1.42503152 2.01047852]
#  [1.4833675  2.2163283 ]]
# norm_f =  0.0922810666929495
# ================= i = 11 =================
# The vertices are not degenerate.
# x =  [[1.38747646 1.90675157]
#  [1.42503152 2.01047852]
#  [1.4833675  2.2163283 ]]
# f(x) =  [0.18377125 0.22160266 0.25908171]
# f_l =  0.183771253491481
# f_s =  0.22160265743345736
# f_h =  0.25908171492714305
# f_r =  0.540148624202249
# contraction
# replace x_h by x_c
# new x =  [[1.38747646 1.90675157]
#  [1.42503152 2.01047852]
#  [1.44481075 2.08747167]]
# norm_f =  0.06122511091946989
# ================= i = 12 =================
# The vertices are not degenerate.
# x =  [[1.38747646 1.90675157]
#  [1.42503152 2.01047852]
#  [1.44481075 2.08747167]]
# f(x) =  [0.18377125 0.22160266 0.1978566 ]
# f_l =  0.183771253491481
# f_s =  0.19785660400767316
# f_h =  0.22160265743345736
# f_r =  0.16699703422600867
# expansion
# replace x_h by x_r
# new x =  [[1.38747646 1.90675157]
#  [1.40725569 1.98374472]
#  [1.44481075 2.08747167]]
# norm_f =  0.05460562320744869
# ================= i = 13 =================
# The vertices are not degenerate.
# x =  [[1.38747646 1.90675157]
#  [1.40725569 1.98374472]
#  [1.44481075 2.08747167]]
# f(x) =  [0.18377125 0.16699703 0.1978566 ]
# f_l =  0.16699703422600867
# f_s =  0.183771253491481
# f_h =  0.19785660400767316
# f_r =  0.1595520092594545
# expansion
# replace x_h by x_r
# new x =  [[1.38747646 1.90675157]
#  [1.40725569 1.98374472]
#  [1.3499214  1.80302461]]
# norm_f =  0.03830459474821865
# ================= i = 14 =================
# The vertices are not degenerate.
# x =  [[1.38747646 1.90675157]
#  [1.40725569 1.98374472]
#  [1.3499214  1.80302461]]
# f(x) =  [0.18377125 0.16699703 0.15955201]
# f_l =  0.1595520092594545
# f_s =  0.16699703422600867
# f_h =  0.183771253491481
# f_r =  0.1382293050943629
# expansion
# replace x_h by x_r
# new x =  [[1.36970063 1.88001777]
#  [1.40725569 1.98374472]
#  [1.3499214  1.80302461]]
# norm_f =  0.04554194839711809
# ================= i = 15 =================
# The vertices are not degenerate.
# x =  [[1.36970063 1.88001777]
#  [1.40725569 1.98374472]
#  [1.3499214  1.80302461]]
# f(x) =  [0.13822931 0.16699703 0.15955201]
# f_l =  0.1382293050943629
# f_s =  0.1595520092594545
# f_h =  0.16699703422600867
# f_r =  0.15050844180492434
# reflection, replace x_h by x_r
# new x =  [[1.36970063 1.88001777]
#  [1.31236635 1.69929766]
#  [1.3499214  1.80302461]]
# norm_f =  0.01648859242108433
# ================= i = 16 =================
# The vertices are not degenerate.
# x =  [[1.36970063 1.88001777]
#  [1.31236635 1.69929766]
#  [1.3499214  1.80302461]]
# f(x) =  [0.13822931 0.15050844 0.15955201]
# f_l =  0.1382293050943629
# f_s =  0.15050844180492434
# f_h =  0.1595520092594545
# f_r =  0.11060258306384203
# expansion
# replace x_h by x_r
# new x =  [[1.36970063 1.88001777]
#  [1.31236635 1.69929766]
#  [1.33214557 1.77629082]]
# norm_f =  0.048949426195612475
# ================= i = 17 =================
# The vertices are not degenerate.
# x =  [[1.36970063 1.88001777]
#  [1.31236635 1.69929766]
#  [1.33214557 1.77629082]]
# f(x) =  [0.13822931 0.15050844 0.11060258]
# f_l =  0.11060258306384203
# f_s =  0.1382293050943629
# f_h =  0.15050844180492434
# f_r =  0.22116190956547455
# contraction
# replace x_h by x_c
# new x =  [[1.36970063 1.88001777]
#  [1.33164472 1.76372598]
#  [1.33214557 1.77629082]]
# norm_f =  0.03139674456067673
# ================= i = 18 =================
# The vertices are not degenerate.
# x =  [[1.36970063 1.88001777]
#  [1.33164472 1.76372598]
#  [1.33214557 1.77629082]]
# f(x) =  [0.13822931 0.1191117  0.11060258]
# f_l =  0.11060258306384203
# f_s =  0.11911169724424761
# f_h =  0.1382293050943629
# f_r =  0.10800677726731453
# expansion
# replace x_h by x_r
# new x =  [[1.29408966 1.65999903]
#  [1.33164472 1.76372598]
#  [1.33214557 1.77629082]]
# norm_f =  0.030222527827048373
# ================= i = 19 =================
# The vertices are not degenerate.
# x =  [[1.29408966 1.65999903]
#  [1.33164472 1.76372598]
#  [1.33214557 1.77629082]]
# f(x) =  [0.10800678 0.1191117  0.11060258]
# f_l =  0.10800677726731453
# f_s =  0.11060258306384203
# f_h =  0.11911169724424761
# f_r =  0.08794006323589322
# expansion
# replace x_h by x_e
# new x =  [[1.29408966 1.65999903]
#  [1.27606341 1.62698281]
#  [1.33214557 1.77629082]]
# norm_f =  0.04271708907230931
# ================= i = 20 =================
# The vertices are not degenerate.
# x =  [[1.29408966 1.65999903]
#  [1.27606341 1.62698281]
#  [1.33214557 1.77629082]]
# f(x) =  [0.10800678 0.07639461 0.11060258]
# f_l =  0.0763946081719383
# f_s =  0.10800677726731453
# f_h =  0.11060258306384203
# f_r =  0.10492246901225
# reflection, replace x_h by x_r
# new x =  [[1.29408966 1.65999903]
#  [1.27606341 1.62698281]
#  [1.2380075  1.51069102]]
# norm_f =  0.005680114051592036
